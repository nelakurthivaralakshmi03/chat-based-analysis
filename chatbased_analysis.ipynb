# %%
#data loading


import re
import pandas as pd

with open("WhatsApp Chat with Megha@sis.txt", encoding="utf-8") as f:
    data = f.read()

# %%
pattern = r'\d{1,2}/\d{1,2}/\d{2},\s\d{2}:\d{2}\s-\s'

messages = re.split(pattern, data)[1:]
dates = re.findall(pattern, data)

print(len(messages), len(dates))
print(messages[:3])
print(dates[:3])
# Out:
# 17641 17641
# ['Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.\n', 'N.Varalakshmi: Hello\n', 'N.Varalakshmi: Megha\n']
# ['8/15/22, 12:54 - ', '8/15/22, 12:54 - ', '8/15/22, 12:54 - ']

# %%
df = pd.DataFrame({
    'user_message': messages,
    'message_date': dates
})

# %%
# convert date to date and time
df['message_date'] = pd.to_datetime(
    df['message_date'],
    format='%m/%d/%y, %H:%M - '
)

# %%
users = []
messages = []

for message in df['user_message']:
    entry = re.split(r'([\w\W]+?):\s', message)

    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['user'] = users
df['message'] = messages

# %%
df['message'] = df['message'].str.replace('\n', '', regex=False)
df['message'] = df['message'].str.strip()
df['message'] = (
    df['message']
    .str.replace('\n', '', regex=False)
    .str.strip()
)

# %%
df.head()
# Out:
#                                         user_message        message_date  \
# 0  Messages and calls are end-to-end encrypted. O... 2022-08-15 12:54:00
# 1                             N.Varalakshmi: Hello\n 2022-08-15 12:54:00
# 2                             N.Varalakshmi: Megha\n 2022-08-15 12:54:00
# 3                         N.Varalakshmi: I am vara\n 2022-08-15 12:54:00
# 4                              Megha@sis: Hlo vara\n 2022-08-15 13:24:00
#
#                  user                                            message
# 0  group_notification  Messages and calls are end-to-end encrypted. O...
# 1       N.Varalakshmi                                              Hello
# 2       N.Varalakshmi                                              Megha
# 3       N.Varalakshmi                                          I am vara
# 4           Megha@sis                                           Hlo vara

# %%
df.shape[0]  #chat volume
# Out:
# 17641

# %%
df['user'].nunique() # no of active users
# Out:
# 3

# %%
# most active user

df['user'].value_counts().head(10)
# Out:
# user
# N.Varalakshmi         9465
# Megha@sis             8175
# group_notification       1
# Name: count, dtype: int64

# %%
#data  anlaysis basic

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17641 entries, 0 to 17640
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_message  17641 non-null  object
#  1   message_date  17641 non-null  datetime64[ns]
#  2   user          17641 non-null  object
#  3   message       17641 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 551.4+ KB

# %%
df.groupby('user').count()['message']
# Out:
# user
# Megha@sis             8175
# N.Varalakshmi         9465
# group_notification       1
# Name: message, dtype: int64

# %%
# message start date

start_date=df['message_date'].min()
start_date
# Out:
# Timestamp('2022-08-15 12:54:00')

# %%
end_date=df['message_date'].max()
end_date
# Out:
# Timestamp('2026-01-12 21:43:00')

# %%
df['user'].value_counts(normalize=True)*100
# Out:
# user
# N.Varalakshmi         53.653421
# Megha@sis             46.340910
# group_notification     0.005669
# Name: proportion, dtype: float64

# %%
df['hour'] = df['message_date'].dt.hour
df
# Out:
#                                             user_message        message_date  \
# 0      Messages and calls are end-to-end encrypted. O... 2022-08-15 12:54:00
# 1                                 N.Varalakshmi: Hello\n 2022-08-15 12:54:00
# 2                                 N.Varalakshmi: Megha\n 2022-08-15 12:54:00
# 3                             N.Varalakshmi: I am vara\n 2022-08-15 12:54:00
# 4                                  Megha@sis: Hlo vara\n 2022-08-15 13:24:00
# ...                                                  ...                 ...
# 17636                               Megha@sis: Hmm. Ok\n 2026-01-11 21:23:00
# 17637                               N.Varalakshmi: Haa\n 2026-01-11 21:23:00
# 17638                                  N.Varalakshmi: \n 2026-01-12 20:30:00
# 17639                                      Megha@sis: \n 2026-01-12 20:46:00
# 17640                                  N.Varalakshmi: \n 2026-01-12 21:43:00
#
#                      user                                            message  \
# 0      group_notification  Messages and calls are end-to-end encrypted. O...
# 1           N.Varalakshmi                                              Hello
# 2           N.Varalakshmi                                              Megha
# 3           N.Varalakshmi                                          I am vara
# 4               Megha@sis                                           Hlo vara
# ...                   ...                                                ...
# 17636           Megha@sis                                            Hmm. Ok
# 17637       N.Varalakshmi                                                Haa
# 17638       N.Varalakshmi
# 17639           Megha@sis
# 17640       N.Varalakshmi
#
#        hour
# 0        12
# 1        12
# 2        12
# 3        12
# 4        13
# ...     ...
# 17636    21
# 17637    21
# 17638    20
# 17639    20
# 17640    21
#
# [17641 rows x 5 columns]

# %%
df['weekday'] = df['message_date'].dt.day_name()
df
# Out:
#                                             user_message        message_date  \
# 0      Messages and calls are end-to-end encrypted. O... 2022-08-15 12:54:00
# 1                                 N.Varalakshmi: Hello\n 2022-08-15 12:54:00
# 2                                 N.Varalakshmi: Megha\n 2022-08-15 12:54:00
# 3                             N.Varalakshmi: I am vara\n 2022-08-15 12:54:00
# 4                                  Megha@sis: Hlo vara\n 2022-08-15 13:24:00
# ...                                                  ...                 ...
# 17636                               Megha@sis: Hmm. Ok\n 2026-01-11 21:23:00
# 17637                               N.Varalakshmi: Haa\n 2026-01-11 21:23:00
# 17638                                  N.Varalakshmi: \n 2026-01-12 20:30:00
# 17639                                      Megha@sis: \n 2026-01-12 20:46:00
# 17640                                  N.Varalakshmi: \n 2026-01-12 21:43:00
#
#                      user                                            message  \
# 0      group_notification  Messages and calls are end-to-end encrypted. O...
# 1           N.Varalakshmi                                              Hello
# 2           N.Varalakshmi                                              Megha
# 3           N.Varalakshmi                                          I am vara
# 4               Megha@sis                                           Hlo vara
# ...                   ...                                                ...
# 17636           Megha@sis                                            Hmm. Ok
# 17637       N.Varalakshmi                                                Haa
# 17638       N.Varalakshmi
# 17639           Megha@sis
# 17640       N.Varalakshmi
#
#        hour weekday
# 0        12  Monday
# 1        12  Monday
# 2        12  Monday
# 3        12  Monday
# 4        13  Monday
# ...     ...     ...
# 17636    21  Sunday
# 17637    21  Sunday
# 17638    20  Monday
# 17639    20  Monday
# 17640    21  Monday
#
# [17641 rows x 6 columns]

# %%
df['month'] = df['message_date'].dt.month_name()
df
# Out:
#                                             user_message        message_date  \
# 0      Messages and calls are end-to-end encrypted. O... 2022-08-15 12:54:00
# 1                                 N.Varalakshmi: Hello\n 2022-08-15 12:54:00
# 2                                 N.Varalakshmi: Megha\n 2022-08-15 12:54:00
# 3                             N.Varalakshmi: I am vara\n 2022-08-15 12:54:00
# 4                                  Megha@sis: Hlo vara\n 2022-08-15 13:24:00
# ...                                                  ...                 ...
# 17636                               Megha@sis: Hmm. Ok\n 2026-01-11 21:23:00
# 17637                               N.Varalakshmi: Haa\n 2026-01-11 21:23:00
# 17638                                  N.Varalakshmi: \n 2026-01-12 20:30:00
# 17639                                      Megha@sis: \n 2026-01-12 20:46:00
# 17640                                  N.Varalakshmi: \n 2026-01-12 21:43:00
#
#                      user                                            message  \
# 0      group_notification  Messages and calls are end-to-end encrypted. O...
# 1           N.Varalakshmi                                              Hello
# 2           N.Varalakshmi                                              Megha
# 3           N.Varalakshmi                                          I am vara
# 4               Megha@sis                                           Hlo vara
# ...                   ...                                                ...
# 17636           Megha@sis                                            Hmm. Ok
# 17637       N.Varalakshmi                                                Haa
# 17638       N.Varalakshmi
# 17639           Megha@sis
# 17640       N.Varalakshmi
#
#        hour weekday    month
# 0        12  Monday   August
# 1        12  Monday   August
# 2        12  Monday   August
# 3        12  Monday   August
# 4        13  Monday   August
# ...     ...     ...      ...
# 17636    21  Sunday  January
# 17637    21  Sunday  January
# 17638    20  Monday  January
# 17639    20  Monday  January
# 17640    21  Monday  January
#
# [17641 rows x 7 columns]

# %%
df['user'].value_counts()
# Out:
# user
# N.Varalakshmi         9465
# Megha@sis             8175
# group_notification       1
# Name: count, dtype: int64

# %%
df['message_length']=df['message'].str.len()
df.groupby('user')['message_length'].mean()  #average message length per user
# Out:
# user
# Megha@sis              19.899083
# N.Varalakshmi          14.150343
# group_notification    117.000000
# Name: message_length, dtype: float64

# %%
# time based analysis
df['hour'].value_counts().sort_index()
# Out:
# hour
# 0      298
# 1       52
# 2       44
# 3        7
# 4       13
# 5       21
# 6      103
# 7      298
# 8      585
# 9      718
# 10     488
# 11     864
# 12     766
# 13     763
# 14     749
# 15     806
# 16     844
# 17     853
# 18    1350
# 19    1550
# 20    1548
# 21    2184
# 22    1651
# 23    1086
# Name: count, dtype: int64

# %%
df['date'] = df['message_date'].dt.date
df.groupby('date').size()
#messages per day
# Out:
# date
# 2022-08-15     62
# 2022-08-16    135
# 2022-08-17     50
# 2022-08-18     56
# 2022-08-19     74
#              ...
# 2026-01-08      7
# 2026-01-09      4
# 2026-01-10     18
# 2026-01-11     43
# 2026-01-12      3
# Length: 806, dtype: int64

# %%
df['mon'] = df['message_date'].dt.to_period('M')
df.groupby('mon').size()
# messages per month
# Out:
# mon
# 2022-08    1275
# 2022-09     911
# 2022-10     778
# 2022-11     670
# 2022-12     410
# 2023-01     289
# 2023-02     222
# 2023-03     328
# 2023-04    1031
# 2023-05     433
# 2023-06     611
# 2023-07     399
# 2023-08     194
# 2023-09    1168
# 2023-10     332
# 2023-11     373
# 2023-12     339
# 2024-01     305
# 2024-02     234
# 2024-03     483
# 2024-04     226
# 2024-05     280
# 2024-06     211
# 2024-07     288
# 2024-08     383
# 2024-09     199
# 2024-10     215
# 2024-11     285
# 2024-12     360
# 2025-01     316
# 2025-02     253
# 2025-03     297
# 2025-04     539
# 2025-05     282
# 2025-06     734
# 2025-07     331
# 2025-08     247
# 2025-09     185
# 2025-10     717
# 2025-11     226
# 2025-12     140
# 2026-01     142
# Freq: M, dtype: int64

# %%
df['hour'].value_counts().sort_index()
# messages per hour
# Out:
# hour
# 0      298
# 1       52
# 2       44
# 3        7
# 4       13
# 5       21
# 6      103
# 7      298
# 8      585
# 9      718
# 10     488
# 11     864
# 12     766
# 13     763
# 14     749
# 15     806
# 16     844
# 17     853
# 18    1350
# 19    1550
# 20    1548
# 21    2184
# 22    1651
# 23    1086
# Name: count, dtype: int64

# %%
# weekday vs weekend activity

df['is_weekend'] = df['message_date'].dt.weekday >= 5
df['is_weekend'].value_counts()
# Out:
# is_weekend
# False    12024
# True      5617
# Name: count, dtype: int64

# %%
df['weekday'].value_counts()
# Out:
# weekday
# Saturday     3253
# Friday       3072
# Thursday     2538
# Tuesday      2364
# Sunday       2364
# Wednesday    2087
# Monday       1963
# Name: count, dtype: int64

# %%
df
# Out:
#                                             user_message        message_date  \
# 0      Messages and calls are end-to-end encrypted. O... 2022-08-15 12:54:00
# 1                                 N.Varalakshmi: Hello\n 2022-08-15 12:54:00
# 2                                 N.Varalakshmi: Megha\n 2022-08-15 12:54:00
# 3                             N.Varalakshmi: I am vara\n 2022-08-15 12:54:00
# 4                                  Megha@sis: Hlo vara\n 2022-08-15 13:24:00
# ...                                                  ...                 ...
# 17636                               Megha@sis: Hmm. Ok\n 2026-01-11 21:23:00
# 17637                               N.Varalakshmi: Haa\n 2026-01-11 21:23:00
# 17638                                  N.Varalakshmi: \n 2026-01-12 20:30:00
# 17639                                      Megha@sis: \n 2026-01-12 20:46:00
# 17640                                  N.Varalakshmi: \n 2026-01-12 21:43:00
#
#                      user                                            message  \
# 0      group_notification  Messages and calls are end-to-end encrypted. O...
# 1           N.Varalakshmi                                              Hello
# 2           N.Varalakshmi                                              Megha
# 3           N.Varalakshmi                                          I am vara
# 4               Megha@sis                                           Hlo vara
# ...                   ...                                                ...
# 17636           Megha@sis                                            Hmm. Ok
# 17637       N.Varalakshmi                                                Haa
# 17638       N.Varalakshmi
# 17639           Megha@sis
# 17640       N.Varalakshmi
#
#        hour weekday    month  message_length
# 0        12  Monday   August             117
# 1        12  Monday   August               5
# 2        12  Monday   August               5
# 3        12  Monday   August               9
# 4        13  Monday   August               8
# ...     ...     ...      ...             ...
# 17636    21  Sunday  January               7
# 17637    21  Sunday  January               3
# 17638    20  Monday  January               0
# 17639    20  Monday  January               0
# 17640    21  Monday  January               0
#
# [17641 rows x 8 columns]

# %%
df['word_count'] = df['message'].apply(lambda x: len(x.split()))
df['word_count'].describe()
# Out:
# count    17641.000000
# mean         2.414035
# std          5.981509
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max        501.000000
# Name: word_count, dtype: float64

# %%
# media links and system messages

df['is_media'] = df['message'].str.contains('<Media omitted>')
df['is_media'].sum()
# Out:
# np.int64(2632)

# %%
df['is_link']=df['message'].str.contains('http')
df['is_link'].sum()
# Out:
# np.int64(223)

# %%
# media count of each user

df.groupby('user')['is_media'].sum()
# Out:
# user
# Megha@sis             1297
# N.Varalakshmi         1335
# group_notification       0
# Name: is_media, dtype: int64

# %%
df.groupby('user')['is_link'].sum()
# Out:
# user
# Megha@sis             112
# N.Varalakshmi         111
# group_notification      0
# Name: is_link, dtype: int64

# %%
from collections import Counter

words=' '.join(df['message']).lower().split()
Counter(words).most_common(10)
# Out:
# [('<media', 2632),
#  ('omitted>', 2632),
#  ('vara', 730),
#  ('ok', 696),
#  ('ha', 636),
#  ('ki', 361),
#  ('lo', 350),
#  ('haa', 323),
#  ('inka', 243),
#  ('sare', 214)]

# %%
# most used emojis
# !pip install emoji
import emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0

# %%
emojis=[]

for msg in df['message']:
  emojis.extend([c for c in msg if c in emoji.EMOJI_DATA])
pd.Series(emojis).value_counts().head(10)
# Out:
# 😁    28
# 🥰    22
# 👍    19
# ❤    19
# 👋    16
# 😂    14
# 😊     8
# 😭     8
# 🥲     8
# ✅     7
# Name: count, dtype: int64

# %%
# behaviour based questions

# average messages per user

df.groupby('user').value_counts().mean()
# Out:
# np.float64(1.1155305425572277)

# %%
# who replies fastest

df['response_time'] = df['message_date'].diff().dt.total_seconds()
df.groupby('user')['response_time'].mean().idxmin()
# Out:
# 'Megha@sis'

# %%
# is chat activity increasing or decrasing

df.groupby(df['message_date'].dt.to_period('M')).size()
